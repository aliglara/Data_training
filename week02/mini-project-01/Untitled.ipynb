# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Business problem
#
# You are a data analyst working for a big box retailer. You’re given a dataset of orders from the past few years, and your job is to answer questions and, if you can, create a set of visualizations that can help the execs get a clear picture of the company’s sales performance. Some questions that were brought up in the last earnings call include:

# %% [markdown]
# ## Data

# %%
file_data = 'Sample+-+Superstore.xlsx'

data = pd.read_excel(file_data)

# %%
print('The dataset has {} entries, and {} attributes'.format(data.shape[0], data.shape[1]))
# Out:
# The dataset has 9994 entries, and 21 attributes

# %%
data.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# ## What are our most popular products?

# %%
unique_country = pd.unique(data['Country'])

# %%
unique_country
# Out:
# array(['United States'], dtype=object)

# %%
data.drop(['Row ID','Country'], axis=1, inplace=True)

# %%
#number of unique products based on ID

num_unique_products = len(set(data['Product ID']))
num_unique_product_names = len(set(data['Product Name']))

# %%
data['Product ID'][data['Product ID']=='FUR-FU-10001889']
# Out:
# 1885    FUR-FU-10001889
# 5901    FUR-FU-10001889
# 6728    FUR-FU-10001889
# 9232    FUR-FU-10001889
# 9574    FUR-FU-10001889
# 9989    FUR-FU-10001889
# Name: Product ID, dtype: object

# %%
data.iloc[1885]
# Out:
# Order ID                 CA-2016-147578
# Order Date          2016-04-22 00:00:00
# Ship Date           2016-04-26 00:00:00
# Ship Mode                  Second Class
# Customer ID                    PG-18895
# Customer Name             Paul Gonzalez
# Segment                        Consumer
# City                      San Francisco
# State                        California
# Postal Code                       94122
# Region                             West
# Product ID              FUR-FU-10001889
# Category                      Furniture
# Sub-Category                Furnishings
# Product Name     Ultra Door Pull Handle
# Sales                             31.56
# Quantity                              3
# Discount                            0.0
# Profit                          10.4148
# Name: 1885, dtype: object

# %%
data.iloc[9574]
# Out:
# Order ID                 CA-2015-148495
# Order Date          2015-08-13 00:00:00
# Ship Date           2015-08-13 00:00:00
# Ship Mode                      Same Day
# Customer ID                    SF-20065
# Customer Name           Sandra Flanagan
# Segment                        Consumer
# City                             Pomona
# State                        California
# Postal Code                       91767
# Region                             West
# Product ID              FUR-FU-10001889
# Category                      Furniture
# Sub-Category                Furnishings
# Product Name     Ultra Door Pull Handle
# Sales                             31.56
# Quantity                              3
# Discount                            0.0
# Profit                          10.4148
# Name: 9574, dtype: object
